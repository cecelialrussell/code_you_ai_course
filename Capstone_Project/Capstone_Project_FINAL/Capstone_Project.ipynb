# %% [markdown]
# ### CODE:YOU AI Pathway - Capstone Project
# ## Smart Personal Finance Analyzer

# %%
import csv
from datetime import datetime
import personal_finance_lib5
transactions = []

def main():
    while True:
        print("\nSmart Personal Finance Analyzer")
        print("1. Load Transactions")
        print("2. Add Transaction")
        print("3. View Transactions")
        print("4. Update Transaction")
        print("5. Delete Transaction")
        print("6. Analyze Finances")
        print("7. Save Transactions")
        print("8. Generate Report")
        print("9. Exit")
        choice = input("Select an option: ")
        if choice == '9':
            break
        elif choice == '1':
            personal_finance_lib5.load_transactions()
        elif choice == '2':
            personal_finance_lib5.add_transactions(transactions)
        elif choice == '3':
            personal_finance_lib5.view_transactions(transactions)
        elif choice == '4':
            personal_finance_lib5.delete_transactions(transactions)


main()
# Out:
# Smart Personal Finance Analyzer
# 1. Load Transactions
# 2. Add Transaction
# 3. View Transactions
# 4. Update Transaction
# 5. Delete Transaction
# 6. Analyze Finances
# 7. Save Transactions
# 8. Generate Report
# 9. Exit
# There are 20 transactions.
# Transaction processing complete. Check errors.txt for any logged issues.
#
# Smart Personal Finance Analyzer
# 1. Load Transactions
# 2. Add Transaction
# 3. View Transactions
# 4. Update Transaction
# 5. Delete Transaction
# 6. Analyze Finances
# 7. Save Transactions
# 8. Generate Report
# 9. Exit
# --- Add New Transaction ---
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 31
#      27         elif choice == '4':
#      28             personal_finance_lib5.delete_transactions(transactions)
# ---> 31 main()
#
# Cell In[5], line 24, in main()
#      22     personal_finance_lib5.load_transactions()
# ...

# %%
import csv
from datetime import datetime
import personal_finance_lib_6

if __name__ == "__main__":

    personal_finance_lib_6.load_transactions()

    while True:
        print("\n--- Smart Personal Finance Analyzer ---")
        print("1. Load Transactions")
        print("2. Add Transactions")
        print("3. View Transactions")
        print("4. Update Transaction")
        print("5. Delete Transaction")
        print("6. Analyze Finances")
        print("7. Save Transactions")
        print("8. Generate Report")
        print("9. Exit")

        choice = input("Enter your choice: ").strip()

        if choice == '1':
            personal_finance_lib_6.load_transactions()
        elif choice == '2':
            personal_finance_lib_6.add_transactions()
        elif choice == '3':
            personal_finance_lib_6.view_transactions(transactions)
        elif choice == '4':
            personal_finance_lib_6.update_transactions()
        elif choice == '5':
            transactions = personal_finance_lib_6.delete_transactions(transactions)
        elif choice == '6':
            print("Feature under construction.")
        elif choice == '7':
            personal_finance_lib_6.save_transactions()
        elif choice == '8':
            print("Feature under contruction.")
        elif choice == '9':
            print("Exiting application. Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")
# Out:
# --- Load Report ---
# There are 40 transactions loaded.
# Current maximum transaction ID: 20
# Transaction processing complete. Check errors.txt for any logged issues.
#
# --- Smart Personal Finance Analyzer ---
# 1. Load Transactions
# 2. Add Transactions
# 3. View Transactions
# 4. Update Transaction
# 5. Delete Transaction
# 6. Analyze Finances
# 7. Save Transactions
# 8. Generate Report
# 9. Exit
# No transactions to display. Load or add some transactions.
#
# --- Smart Personal Finance Analyzer ---
# 1. Load Transactions
# 2. Add Transactions
# 3. View Transactions
# 4. Update Transaction
# 5. Delete Transaction
# 6. Analyze Finances
# 7. Save Transactions
# 8. Generate Report
# 9. Exit
#
# No transactions to display. Load or add some transactions.
#
# --- Smart Personal Finance Analyzer ---
# 1. Load Transactions
# 2. Add Transactions
# 3. View Transactions
# 4. Update Transaction
# 5. Delete Transaction
# 6. Analyze Finances
# 7. Save Transactions
# 8. Generate Report
# ...
